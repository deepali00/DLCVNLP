# %%
#importing libraries
import numpy as np
import pandas as pd 
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
tf.keras.__version__
# Out:
# '2.5.0'

# %%
# classification of mnist data
# image is of 28x28 pixel
#it has 10 class
# Its the example of multi classification

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train_full, y_train_full),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 4s 0us/step

# %%
x_train_full.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train_full.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %%
#checking data type
x_train_full.dtype
# Out:
# dtype('uint8')

# %%
# creating a validation set
x_valid , x_train = x_train_full[:5000]/255.0 , x_train_full[5000:]/255.0

# %%
y_valid , y_train = y_train_full[:5000], y_train_full[5000:]

# %%
plt.imshow(x_train[0],cmap='binary')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(x_train[0],annot = True, cmap='binary')
# Out:
# <AxesSubplot:>

# %%
# now we will define the layers for our model

# %%
model = tf.keras.models.Sequential()

# %%
#now we will add layers to ur model
model.add(tf.keras.layers.Flatten(input_shape=[28,28]))
model.add(tf.keras.layers.Dense(300,activation='relu'))
model.add(tf.keras.layers.Dense(100,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
784*300+300 + 300*100+100 + 100*10+10
# Out:
# 266610

# %%
LOSS_FUNCTION = 'sparse_categorical_crossentropy'
OPTIMIZER = 'SGD'
METRICS = 'accuracy'
model.compile(loss =LOSS_FUNCTION, optimizer = OPTIMIZER, metrics = METRICS )

# %%
EPOCHS =35
VALIDATION_SET = (x_valid,y_valid)
history = model.fit(x_train, y_train, epochs = EPOCHS, validation_data = VALIDATION_SET)
# Out:
# Epoch 1/35
# 1719/1719 [==============================] - 5s 2ms/step - loss: 0.5816 - accuracy: 0.8496 - val_loss: 0.3003 - val_accuracy: 0.9162 ETA: 0s - loss: 0
# Epoch 2/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2849 - accuracy: 0.9188 - val_loss: 0.2345 - val_accuracy: 0.9352
# Epoch 3/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.2314 - accuracy: 0.9338 - val_loss: 0.1975 - val_accuracy: 0.9468
# Epoch 4/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1968 - accuracy: 0.9439 - val_loss: 0.1718 - val_accuracy: 0.9526 - loss: 0.2112 - accuracy: 0.94 - ETA: 2s - loss: 0.2109 - accuracy:  - ETA: 1s - los
# Epoch 5/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1712 - accuracy: 0.9509 - val_loss: 0.1514 - val_accuracy: 0.9582
# Epoch 6/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1511 - accuracy: 0.9569 - val_loss: 0.1402 - val_accuracy: 0.9616
# Epoch 7/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1352 - accuracy: 0.9616 - val_loss: 0.1277 - val_accuracy: 0.9654 l - ETA: 0s - loss: 0.1350 - accuracy: 0.
# Epoch 8/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1221 - accuracy: 0.9658 - val_loss: 0.1175 - val_accuracy: 0.9696
# Epoch 9/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1113 - accuracy: 0.9681 - val_loss: 0.1101 - val_accuracy: 0.9710.112
# Epoch 10/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.1017 - accuracy: 0.9715 - val_loss: 0.1045 - val_accuracy: 0.9712TA: 1s - loss: 0.1018 - accura -
# Epoch 11/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0930 - accuracy: 0.9738 - val_loss: 0.1020 - val_accuracy: 0.9718
# Epoch 12/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0860 - accuracy: 0.9757 - val_loss: 0.0961 - val_accuracy: 0.9718 0.0862
# Epoch 13/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0797 - accuracy: 0.9778 - val_loss: 0.0911 - val_accuracy: 0.9738
# Epoch 14/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0737 - accuracy: 0.9794 - val_loss: 0.0888 - val_accuracy: 0.9746
# Epoch 15/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0685 - accuracy: 0.9811 - val_loss: 0.0859 - val_accuracy: 0.9738
# Epoch 16/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0639 - accuracy: 0.9826 - val_loss: 0.0834 - val_accuracy: 0.9746 0
# Epoch 17/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0594 - accuracy: 0.9839 - val_loss: 0.0800 - val_accuracy: 0.9764
# Epoch 18/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0557 - accuracy: 0.9849 - val_loss: 0.0788 - val_accuracy: 0.9774
# Epoch 19/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0522 - accuracy: 0.9867 - val_loss: 0.0766 - val_accuracy: 0.9780
# Epoch 20/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0492 - accuracy: 0.9877 - val_loss: 0.0757 - val_accuracy: 0.9782
# Epoch 21/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0461 - accuracy: 0.9880 - val_loss: 0.0739 - val_accuracy: 0.9780
# Epoch 22/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0433 - accuracy: 0.9889 - val_loss: 0.0745 - val_accuracy: 0.9794
# Epoch 23/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0408 - accuracy: 0.9894 - val_loss: 0.0732 - val_accuracy: 0.9786
# Epoch 24/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0382 - accuracy: 0.9903 - val_loss: 0.0712 - val_accuracy: 0.9792: 1s - loss:
# Epoch 25/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0363 - accuracy: 0.9909 - val_loss: 0.0709 - val_accuracy: 0.9788
# Epoch 26/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0339 - accuracy: 0.9919 - val_loss: 0.0702 - val_accuracy: 0.9798
# Epoch 27/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0320 - accuracy: 0.9923 - val_loss: 0.0694 - val_accuracy: 0.9798
# Epoch 28/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0303 - accuracy: 0.9931 - val_loss: 0.0713 - val_accuracy: 0.9788
# Epoch 29/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0285 - accuracy: 0.9936 - val_loss: 0.0714 - val_accuracy: 0.9798
# Epoch 30/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0271 - accuracy: 0.9939 - val_loss: 0.0715 - val_accuracy: 0.9800
# Epoch 31/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0257 - accuracy: 0.9945 - val_loss: 0.0759 - val_accuracy: 0.9782
# Epoch 32/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0242 - accuracy: 0.9949 - val_loss: 0.0685 - val_accuracy: 0.9806TA: 0s - loss: 0.024
# Epoch 33/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0229 - accuracy: 0.9955 - val_loss: 0.0699 - val_accuracy: 0.9808
# Epoch 34/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0216 - accuracy: 0.9957 - val_loss: 0.0676 - val_accuracy: 0.9810
# Epoch 35/35
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.0205 - accuracy: 0.9962 - val_loss: 0.0685 - val_accuracy: 0.9816
